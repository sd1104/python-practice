# %% [markdown]
# 階乗
# $$ n! = n \times (n - 1) \times (n-2) ..... 3 \times 2 \times 1 $$
#
# 順列
# $$ {}_n \mathrm{ P }_r = \frac{n!}{(n-r)!} $$
#
#
# 組み合わせ
# $$ {}_n \mathrm{ C }_r = \frac{n!}{r!(n-r)!} $$
#
#
# 繰り返しありの順列
# $$ n^r $$
#
# 繰り返しなしの組み合わせ
#
#
# 空集合
#
#
# 部分集合
#
# 補集合
#
# 和集合
#
# 積集合
#
# 標本空間
#
# 事象
#
# 標本点
#
# 平均mean
#
#
# 中央値median
#
# 分散
#
# 標準偏差
#
# 変動係数
#
# 標準化
#
# 標準得点
#
# T得点
#
# スタージェンスの公式
#
# 積偏差
#
# 共分散
#
# 相関係数（積立相関係数）
#
# ラプラスの定義
#
# 期待値
#
# 条件付き確立
#
# 乗法定理
#
# ベイズの定理
#
#
#
# $$
